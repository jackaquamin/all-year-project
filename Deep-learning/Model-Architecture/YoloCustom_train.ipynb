# %%
# !yolo train model=yolov8n.pt data=data.yaml epochs=1 imgsz=50 save=True
# Out:
# New https://pypi.org/project/ultralytics/8.0.70 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.58  Python-3.11.2 torch-2.0.0+cpu CPU
# ...
